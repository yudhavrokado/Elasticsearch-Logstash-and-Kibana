# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-baf368f80de7> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
raw = pd.read_csv("dtksjan20_pupr.csv", header=0)
random = np.random.randint(0,1036452, size=1036452)
df = pd.DataFrame(raw)
df.reset_index()
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036451 entries, 0 to 1036450
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   nmprop                1036451 non-null  object
#  1   nmkab                 1036451 non-null  object
#  2   nmkec                 1036426 non-null  object
#  3   nmdesa                1036303 non-null  object
#  4   pekerjaan_utama       1036451 non-null  object
#  5   kepemilikan_rumah     1036451 non-null  object
#  6   luas_lantai           1036451 non-null  int64
#  7   Jumlah_ART            1036451 non-null  int64
#  8   Stdt_luas_rmh         1036451 non-null  object
#  9   lantai_terluas        1036451 non-null  object
#  10  dinding_terluas       1036451 non-null  object
#  11  atap_terluas          1036451 non-null  object
#  12  Stdt_bangunan_rumah   1036451 non-null  object
#  13  sumber_airminum       1036451 non-null  object
#  14  Stdt_sumber_airminum  1036451 non-null  object
#  15  fasilitas_bab         1036451 non-null  object
#  16  jenis_kloset          1036451 non-null  object
#  17  pembuangan_tinja      1036451 non-null  object
#  18  Stdt_sanitasi         1036451 non-null  object
#  19  rumah_layak_huni      1036451 non-null  object
#  20  kategori              914309 non-null   object
#  21  Jumlah_bansos_rutin   1036444 non-null  float64
# dtypes: float64(1), int64(2), object(19)
# memory usage: 98.8+ MB

# %%
df['id'] = np.random.randint(0,1036452, df.shape[0])

# %%
df.head()
# Out:
#   nmprop     nmkab          nmkec        nmdesa      pekerjaan_utama  \
# 0   ACEH  SIMEULUE  TEUPAH TENGAH  BUSUNG INDAH              Lainnya
# 1   ACEH  SIMEULUE  TEUPAH TENGAH  BUSUNG INDAH              Lainnya
# 2   ACEH  SIMEULUE  TEUPAH TENGAH  BUSUNG INDAH  Hotel & rumah makan
# 3   ACEH  SIMEULUE  TEUPAH TENGAH  BUSUNG INDAH  Jasa kemasyarakatan
# 4   ACEH  SIMEULUE  TEUPAH TENGAH  BUSUNG INDAH  Jasa kemasyarakatan
#
#   kepemilikan_rumah  luas_lantai  Jumlah_ART Stdt_luas_rmh    lantai_terluas  \
# 0     Milik sendiri           77           3         Layak  Semen/bata merah
# 1     Milik sendiri           36           1         Layak  Semen/bata merah
# 2     Milik sendiri           49           9   Tidak Layak  Semen/bata merah
# 3           Lainnya           30           2         Layak  Semen/bata merah
# 4     Milik sendiri           25           3         Layak  Semen/bata merah
#
#    ...   sumber_airminum Stdt_sumber_airminum fasilitas_bab jenis_kloset  \
# 0  ...     Air isi ulang                Layak     Tidak ada  Tidak pakai
# 1  ...  Sumur terlindung                Layak       Sendiri  Leher angsa
# 2  ...     Air isi ulang                Layak       Sendiri  Leher angsa
# 3  ...     Air isi ulang                Layak     Tidak ada  Tidak pakai
# 4  ...     Air isi ulang                Layak     Tidak ada  Tidak pakai
#
#                 pembuangan_tinja Stdt_sanitasi rumah_layak_huni kategori  \
# 0  Kolam/sawah/sungai/danau/laut   Tidak Layak      Tidak layak    Mampu
# 1                         Tangki         Layak            Layak    Mampu
# 2                         Tangki         Layak      Tidak layak    Mampu
# 3      Pantai/tanah lapang/kebun   Tidak Layak      Tidak layak    Mampu
# 4                        Lainnya   Tidak Layak      Tidak layak    Mampu
#
#   Jumlah_bansos_rutin      id
# 0                 0.0  564748
# 1                 1.0  330907
# 2                 0.0  246751
# 3                 1.0  680554
# 4                 1.0  522202
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1036451 entries, 0 to 1036450
# Data columns (total 23 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   nmprop                1036451 non-null  object
#  1   nmkab                 1036451 non-null  object
#  2   nmkec                 1036426 non-null  object
#  3   nmdesa                1036303 non-null  object
#  4   pekerjaan_utama       1036451 non-null  object
#  5   kepemilikan_rumah     1036451 non-null  object
#  6   luas_lantai           1036451 non-null  int64
#  7   Jumlah_ART            1036451 non-null  int64
#  8   Stdt_luas_rmh         1036451 non-null  object
#  9   lantai_terluas        1036451 non-null  object
#  10  dinding_terluas       1036451 non-null  object
#  11  atap_terluas          1036451 non-null  object
#  12  Stdt_bangunan_rumah   1036451 non-null  object
#  13  sumber_airminum       1036451 non-null  object
#  14  Stdt_sumber_airminum  1036451 non-null  object
#  15  fasilitas_bab         1036451 non-null  object
#  16  jenis_kloset          1036451 non-null  object
#  17  pembuangan_tinja      1036451 non-null  object
#  18  Stdt_sanitasi         1036451 non-null  object
#  19  rumah_layak_huni      1036451 non-null  object
#  20  kategori              914309 non-null   object
#  21  Jumlah_bansos_rutin   1036444 non-null  float64
#  22  id                    1036451 non-null  int32
# dtypes: float64(1), int32(1), int64(2), object(19)
# memory usage: 102.8+ MB

# %%
import re
import json
from datetime import datetime
from pprint import pprint
import timeit
class SetEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.int64):
            return np.int(obj)
        # else
        return json.JSONEncoder.default(self, obj)

# %%
try:
    import os
    import sys
    import elasticsearch
    from elasticsearch import Elasticsearch
    from elasticsearch import helpers
    import csv
    import requests
    
    print("All modules are loaded")
except Exception as e:
    print("Some module are missing".format(e))
# Out:
# All modules are loaded

# %%
res = requests.get('http://10.17.5.101:9200/')
print(res.content)
# Out:
# b'{\n  "name" : "semantic101",\n  "cluster_name" : "semanticDB",\n  "cluster_uuid" : "DDJhcfKTTuiO7RBCXE6mZA",\n  "version" : {\n    "number" : "7.6.1",\n    "build_flavor" : "default",\n    "build_type" : "rpm",\n    "build_hash" : "aa751e09be0a5072e8570670309b1f12348f023b",\n    "build_date" : "2020-02-29T00:15:25.529771Z",\n    "build_snapshot" : false,\n    "lucene_version" : "8.4.0",\n    "minimum_wire_compatibility_version" : "6.8.0",\n    "minimum_index_compatibility_version" : "6.0.0-beta1"\n  },\n  "tagline" : "You Know, for Search"\n}\n'

# %%
es = Elasticsearch("http://10.17.5.101:9200", timeout=30, max_retries=10, retry_on_timeout=True)
es.ping()
# Out:
# True

# %%
df2 = df.to_dict('records')

# %%
df2[0]
# Out:
# {'nmprop': 'ACEH',
#  'nmkab': 'SIMEULUE',
#  'nmkec': 'TEUPAH TENGAH',
#  'nmdesa': 'BUSUNG INDAH',
#  'pekerjaan_utama': 'Lainnya',
#  'kepemilikan_rumah': 'Milik sendiri',
#  'luas_lantai': 77,
#  'Jumlah_ART': 3,
#  'Stdt_luas_rmh': 'Layak',
#  'lantai_terluas': 'Semen/bata merah',
#  'dinding_terluas': 'Kayu/papan',
#  'atap_terluas': 'Seng',
#  'Stdt_bangunan_rumah': 'Layak',
#  'sumber_airminum': 'Air isi ulang',
#  'Stdt_sumber_airminum': 'Layak',
#  'fasilitas_bab': 'Tidak ada',
#  'jenis_kloset': 'Tidak pakai',
#  'pembuangan_tinja': 'Kolam/sawah/sungai/danau/laut',
#  'Stdt_sanitasi': 'Tidak Layak',
#  'rumah_layak_huni': 'Tidak layak',
#  'kategori': 'Mampu',
#  'Jumlah_bansos_rutin': 0.0,
#  'id': 564748}

# %%
def generator(df2):
    for c, line in enumerate(df2):
        yield{
    '_index': 'dtksjan20_hashed',
    '_type': '_doc',
    '_id':line.get("id", None),
    '_source': {
        'nmprop':line.get('nmprop', ""),
        'nmkab':line.get('nmkab', ""),
        'nmkec':line.get('nmkec', ""),
        'nmdesa':line.get('nmdesa', ""),
        'pekerjaan_utama':line.get('pekerjaan_utama', ""),
        'kepemilikan_rumah':line.get('kepemilikan_rumah', ""),
        'luas_lantai':line.get('luas_lantai', ""),
        'jumlah_art':line.get('Jumlah_ART', ""),
        'Stdt_luas_rumah':line.get('Stdt_luas_rumah', ""),
        'lantai_terluas':line.get('lantai_terluas', ""),
        'dinding_terluas':line.get('dinding_terluas', ""),
        'atap_terluas':line.get('atap_terluas', ""),\
        'Stdt_bangunan_rumah':line.get('Stdt_bangunan_rumah', ""),
        'sumber_airminum':line.get('sumber_airminum', ""),
        'Stdt_sumber_airminum':line.get('Stdt_sumber_airminum', ""),
        'fasilitas_bab':line.get('fasilitas_bab', ""),
        'jenis_kloset':line.get('jenis_kloset', ""),
        'pembuangan_tinja':line.get('pembuangan_tinja', ""),
        'Stdt_sanitasi':line.get('Stdt_sanitasi', ""),
        'rumah_layak_huni':line.get('rumah_layak_huni', ""),
        'kategori':line.get('kategori', ""),
        'jumlah_bansos_rutin':line.get('Jumlah_bansos_rutin', "")
    }
        }
    raise StopIteration

# %%
test = generator(df2)

# %%
next(test)
# Out:
# {'_index': 'dtksjan20_hashed',
#  '_type': '_doc',
#  '_id': 564748,
#  '_source': {'nmprop': 'ACEH',
#   'nmkab': 'SIMEULUE',
#   'nmkec': 'TEUPAH TENGAH',
#   'nmdesa': 'BUSUNG INDAH',
#   'pekerjaan_utama': 'Lainnya',
#   'kepemilikan_rumah': 'Milik sendiri',
#   'luas_lantai': 77,
#   'jumlah_art': 3,
#   'Stdt_luas_rumah': '',
#   'lantai_terluas': 'Semen/bata merah',
#   'dinding_terluas': 'Kayu/papan',
#   'atap_terluas': 'Seng',
#   'Stdt_bangunan_rumah': 'Layak',
#   'sumber_airminum': 'Air isi ulang',
#   'Stdt_sumber_airminum': 'Layak',
#   'fasilitas_bab': 'Tidak ada',
#   'jenis_kloset': 'Tidak pakai',
#   'pembuangan_tinja': 'Kolam/sawah/sungai/danau/laut',
#   'Stdt_sanitasi': 'Tidak Layak',
#   'rumah_layak_huni': 'Tidak layak',
#   'kategori': 'Mampu',
#   'jumlah_bansos_rutin': 0.0}}

# %%
mapping = {
   "settings":{
      "number_of_shards":1,
      "number_of_replicas":0
   },
   "mappings":{
      "properties":{
         "nmprop":{
            "type":"keyword"
         },
         "nmkab":{
            "type":"keyword"
         },
         "nmkec":{
            "type":"keyword"
         },
         "nmdesa":{
            "type":"keyword"
         },
         "pekerjaan_utama":{
            "type":"text"
         },
         "kepemilikan_rumah":{
            "type":"keyword"
         },
         "luas_lantai":{
            "type":"integer"
         },
         "Jumlah_ART":{
            "type":"integer"
         },
         "Stdt_luas_rumah":{
            "type":"text"
         },
         "lantai_terluas":{
            "type":"text"
         },
         "dinding_terluas":{
            "type":"text"
         },
         "atap_terluas":{
            "type":"text"
         },
         "Stdt_bangunan_rumah":{
            "type":"text"
         },
         "sumber_airminum":{
            "type":"text"
         },
         "Stdt_sumber_ariminum":{
            "type":"text"
         },
         "fasilitas_bab":{
            "type":"text"
         },
         "jenis_kloset":{
            "type":"text"
         },
         "pembuangan_tinja":{
            "type":"text"
         },
         "Stdt_sanitasi":{
            "type":"text"
         },
         "rumah_layak_huni":{
            "type":"text"
         },
         "kategori":{
            "type":"text"
         },
         "Jumlah_bansos_rutin":{
            "type":"integer"
         }
      }
   }
}

# %%
Indexname = ''
testing = es.indices.create(index='dtksjan20_hashed', body=mapping, ignore=[400,404])

# %%
testing
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'index': 'dtksjan20_hashed'}

# %%
for success, info in helpers.parallel_bulk(es,generator(df2),index='dtksjan20_hashed',doc_type='_doc', thread_count=8, rewuest_timeout=20.0):
    if not success:
        print('A document failed', info)

# %%
try:
    res = helpers.bulk(es,generator(df2))
    print("Working")
except Exception as e:
    pass

# %%
if es.indices.exists(index_name):
    es.indices.delete(index_name)

# %%
es.indices.create(index=index_name,body=mapping)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'dtksjan20_pupr'}

# %%
with open('dtksjan20_pupr.csv') as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index=index_name, doc_type=doc_name)
    for success, info in parallel_bulk(...):
        if not success:
            print('A document failed:', info)
# Out:
# ---------------------------------------------------------------------------
# BulkIndexError                            Traceback (most recent call last)
# <ipython-input-16-e20b4cb83422> in <module>
#       1 with open('dtksjan20_pupr.csv') as f:
#       2     reader = csv.DictReader(f)
# ----> 3     helpers.bulk(es, reader, index=index_name, doc_type=doc_name)
#       4     for success, info in parallel_bulk(...):
#       5         if not success:
#
# c:\users\ytrm\appdata\local\programs\python\python38-32\lib\site-packages\elasticsearch\helpers\actions.py in bulk(client, actions, stats_only, *args, **kwargs)
#     371     # make streaming_bulk yield successful results so we can count them
#     372     kwargs["yield_ok"] = True
# --> 373     for ok, item in streaming_bulk(client, actions, *args, **kwargs):
#     374         # go through request-response pairs and detect failures
#     375         if not ok:
#
# c:\users\ytrm\appdata\local\programs\python\python38-32\lib\site-packages\elasticsearch\helpers\actions.py in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, *args, **kwargs)
#     292
#     293             try:
# --> 294                 for data, (ok, info) in zip(
#     295                     bulk_data,
#     296                     _process_bulk_chunk(
#
# c:\users\ytrm\appdata\local\programs\python\python38-32\lib\site-packages\elasticsearch\helpers\actions.py in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, *args, **kwargs)
#     228             resp=resp, bulk_data=bulk_data, raise_on_error=raise_on_error
#     229         )
# --> 230     for item in gen:
#     231         yield item
#     232
#
# c:\users\ytrm\appdata\local\programs\python\python38-32\lib\site-packages\elasticsearch\helpers\actions.py in _process_bulk_chunk_success(resp, bulk_data, raise_on_error)
#     169
#     170     if errors:
# --> 171         raise BulkIndexError("%i document(s) failed to index." % len(errors), errors)
#     172
#     173
#
# BulkIndexError: ('500 document(s) failed to index.', [{'index': {'_index': 'dtksjan20_pupr', '_type': 'dtksjan', '_id': 'apTvR3YBAaJjyv_EH31q', 'status': 400, 'error': {'type': 'illegal_argument_exception', 'reason': 'Rejecting mapping update to [dtksjan20_pupr] as the final mapping would have more than 1 type: [_doc, dtksjan]'}, 'data': {'nmprop': 'ACEH', 'nmkab': 'SIMEULUE', 'nmkec': 'TEUPAH TENGAH', 'nmdesa': 'BUSUNG INDAH', 'pekerjaan_utama': 'Lainnya', 'kepemilikan_rumah': 'Milik sendiri', 'luas_lantai': '77', 'Jumlah_ART': '3', 'Stdt_luas_rmh': 'Layak', 'lantai_terluas': 'Semen/bata merah', 'dinding_terluas': 'Kayu/papan', 'atap_terluas': 'Seng', 'Stdt_bangunan_rumah': 'Layak', 'sumber_airminum': 'Air isi ulang', 'Stdt_sumber_airminum': 'Layak', 'fasilitas_bab': 'Tidak ada', 'jenis_kloset': 'Tidak pakai', 'pembuangan_tinja': 'Kolam/sawah/sungai/danau/laut', 'Stdt_sanitasi': 'Tidak Layak', 'rumah_layak_huni': 'Tidak layak', 'kategori': 'Mampu', 'Jumlah_bansos_rutin': '0.0'}}}, {'index': {'_index': 'dtksjan20_pupr', '_type': 'dtksjan', '_id': 'a5TvR3YBAaJjyv_EH31q', 'status': 400, 'error': {'type': 'illegal_argument_exception', 'reason': 'Rejecting mapping update to [dtksjan20_pupr] as the final mapping would have more than 1 type: [_doc, dtksjan]'}, 'data': {'nmprop': 'ACEH', 'nmkab': 'SIMEULUE', 'nmkec': 'TEUPAH TENGAH', 'nmdesa': 'BUSUNG INDAH', 'pekerjaan_utama': 'Lainnya', 'kepemilikan_rumah': 'Milik sendiri', 'luas_lantai': '36', 'Jumlah_ART': '1', 'Stdt_luas_rmh': 'Layak', 'lantai_terluas': 'Semen/bata merah', 'dinding_terluas': 'Tembok', 'atap_terluas': 'Seng', 'Stdt_bangunan_rumah': 'Layak', 'sumber_airminum': 'Sumur terlindung', 'Stdt_sumber_airminum': 'Layak', 'fasilitas_bab': 'Sendiri', 'jenis_kloset': 'Leher angsa', 'pembuangan_tinja': 'Tangki', 'Stdt_sanitasi': 'Layak', 'rumah_layak_huni': 'Layak', 'kategori': 'Mampu', 'Jumlah_bansos_rutin': '1.0'}}}, {'index': {'_index': 'dtksjan20_pupr', '_type': 'dtksjan', '_id': 'bJTvR3YBAaJjyv_EH31q', 'status': 400, 'error': {'type': 'illegal_argument_exception', 'reason': 'Rejecting mapping update to [dtksjan20_pupr] as the final mapping would have more than 1 type: [_doc, dtksjan]'}, 'data': {'nmprop': 'ACEH', 'nmkab': 'SIMEULUE', 'nmkec': 'TEUPAH TENGAH', 'nmdesa': 'BUSUNG INDAH', 'pekerjaan_utama': 'Hotel & rumah makan', 'kepemilikan_rumah': 'Milik sendiri', 'luas_lantai': '49', 'Jumlah_ART': '9', 'Stdt_luas_rmh': 'Tidak Layak', 'lantai_terluas': 'Semen/bata merah', 'dinding_terluas': 'Kayu/papan', 'atap_terluas': 'Seng', 'Stdt_bangunan_rumah': 'Layak', 'sumber_airminum': 'Air isi ulang', 'Stdt_sumber_airminum': 'Layak', 'fasilitas_bab': 'Sendiri', 'jenis_kloset': 'Leher angsa', 'pembuangan_tinja': 'Tangki', 'Stdt_sanitasi': 'Layak', 'rumah_layak_huni': 'Tidak layak', 'kategori': 'Mampu', 'Jumlah_bansos_rutin': '0.0'}}}, {'index': {'_index': 'dtksjan20_pupr', '_type': 'dtksjan', '_id': 'bZTvR3YBAaJjyv_EH31q', 'status': 400, 'error': {'type': 'illegal_argument_exception', 'reason': 'Rejecting mapping update to [dtksjan20_pupr] as the final mapping would have more than 1 type: [_doc, dtksjan]'}, 'data': {'nmprop': 'ACEH', 'nmkab': 'SIMEULUE', 'nmkec': 'TEUPAH TENGAH', 'nmdesa': 'BUSUNG INDAH', 'pekerjaan_utama': 'Jasa kemasyarakatan', 'kepemilikan_rumah': 'Lainnya', 'luas_lantai': '30', 'Jumlah_ART': '2', 'Stdt_luas_rmh': 'Layak', 'lantai_terluas': 'Semen/bata merah', 'dinding_terluas': 'Kayu/papan', 'atap_terluas': 'Seng', 'Stdt_bangunan_rumah': 'Layak', 'sumber_airminum': 'Air isi ulang', 'Stdt_sumber_airminum': 'Layak', 'fasilitas_bab': 'Tidak ada', 'jenis_kloset': 'Tidak pakai', 'pembuangan_tinja': 'Pantai/tanah lapang/kebun', 'Stdt_sanitasi': 'Tidak Layak', 'rumah_layak_huni': 'Tidak layak', 'kategori': 'Mampu', 'Jumlah_bansos_rutin': '1.0'}}}, {'index': {'_index': 'dtksjan20_pupr', '_type': 'dtksjan', '_id': 'bpTvR3YBAaJjyv_EH31q', 'status': 400, 'error': {'type': 'illegal_argument_exception', 'reason': 'Rejecting mapping update to [dtksjan20_pupr] as the final m ...

# %%
def read_data(data):
    for doc_id, DTKSjan20_pupr_hashed in raw.iterrows():
        # print every 10000 iteration
        if doc_id % 10000 == 0:
            print(doc_id)
        doc={}
        doc["_index"]=index_name
        doc["_id"]=DTKSjan20_pupr_hashed['_id']
        doc["_type"]=doc_name
        doc["_source"]=DTKSjan20_pupr_hashed.to_dict()
        yield doc
